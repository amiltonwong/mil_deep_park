# %%
import numpy as np
import cv2
import csv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import os, shutil

# %%
"""# Directories for our training, validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)
"""

# %%
"""
# Directory with our training free pictures
train_free_dir = os.path.join(train_dir, 'free')
os.mkdir(train_free_dir)

# Directory with our training busy pictures
train_busy_dir = os.path.join(train_dir, 'busy')
os.mkdir(train_busy_dir)

# Directory with our validation free pictures
validation_free_dir = os.path.join(validation_dir, 'free')
os.mkdir(validation_free_dir)

# Directory with our validation busy pictures
validation_busy_dir = os.path.join(validation_dir, 'busy')
os.mkdir(validation_busy_dir)

# Directory with our testing free pictures
test_free_dir = os.path.join(test_dir, 'free')
os.mkdir(test_free_dir)

# Directory with our testing busy pictures
test_busy_dir = os.path.join(test_dir, 'busy')
os.mkdir(test_busy_dir)
"""

# %%
# based on train.txt/validation.txt/test.txt
train_file_name = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/train.txt"
validation_file_name = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/validation.txt"
test_file_name = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/test.txt"

# %%
# read txt file
lines = []

txt_file = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/train.txt"
with open(txt_file, "r") as txtfile:
    reader = txtfile.readlines()
    for line in reader:
        #print(line)
        lines.append(line)

# %%
len(lines), lines[0:2]
# Out:
# (94493,
#  ['SUNNY/2015-11-12/camera8/S_2015-11-12_12.26_C08_280.jpg 1\n',
#   'OVERCAST/2015-11-25/camera8/O_2015-11-25_10.00_C08_212.jpg 1\n'])

# %%
line = lines[0]

# %%
line[:-3]
# Out:
# 'SUNNY/2015-11-12/camera8/S_2015-11-12_12.26_C08_280.jpg'

# %%
tmp_line = line[:-3]

# %%
tmp_line
# Out:
# 'SUNNY/2015-11-12/camera8/S_2015-11-12_12.26_C08_280.jpg'

# %%
tmp_line.split('/')[-1]
# Out:
# 'S_2015-11-12_12.26_C08_280.jpg'

# %%
int(line[-2:-1])==1
# Out:
# True

# %%
/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/SUNNY/2015-11-12/camera8/S_2015-11-12_12.26_C08_280.jpg

# %%
# copy train files
for line in lines:
    relative_path = line[:-3]
    fname = relative_path.split('/')[-1]
    label = int(line[-2:-1])
    abs_path = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/" + relative_path
    # use cv2.imread() to load image patches (loaded as BGR format)
    #img = cv2.imread(abs_path)
    # use matplotlib.image to load image patches (loaded as RGB format)
    #img = mpimg.imread(abs_path)
    
    # Copy first 1000 free images to train_free_dir
    if (label==0): # free image
        src = abs_path
        dst = os.path.join("/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/train/free",fname)
        shutil.copyfile(src, dst)
    if (label==1): # busy image
        src = abs_path
        dst = os.path.join("/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/train/busy",fname)
        shutil.copyfile(src, dst)

# %%
# read validation.txt file
lines = []

txt_file = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/val.txt"
with open(txt_file, "r") as txtfile:
    reader = txtfile.readlines()
    for line in reader:
        #print(line)
        lines.append(line)
        
# copy validation files
for line in lines:
    relative_path = line[:-3]
    fname = relative_path.split('/')[-1]
    label = int(line[-2:-1])
    abs_path = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/" + relative_path
    # use cv2.imread() to load image patches (loaded as BGR format)
    #img = cv2.imread(abs_path)
    # use matplotlib.image to load image patches (loaded as RGB format)
    #img = mpimg.imread(abs_path)
    
    # Copy free images to validation_free_dir
    if (label==0): # free image
        src = abs_path
        dst = os.path.join("/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/validation/free",fname)
        shutil.copyfile(src, dst)
    # Copy busy images to validation_busy_dir
    if (label==1): # busy image
        src = abs_path
        dst = os.path.join("/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/validation/busy",fname)
        shutil.copyfile(src, dst)

# %%
# read test.txt file
lines = []

txt_file = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/test.txt"
with open(txt_file, "r") as txtfile:
    reader = txtfile.readlines()
    for line in reader:
        #print(line)
        lines.append(line)
        
# copy test files
for line in lines:
    relative_path = line[:-3]
    fname = relative_path.split('/')[-1]
    label = int(line[-2:-1])
    abs_path = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/" + relative_path
    # use cv2.imread() to load image patches (loaded as BGR format)
    #img = cv2.imread(abs_path)
    # use matplotlib.image to load image patches (loaded as RGB format)
    #img = mpimg.imread(abs_path)
    
    # Copy free images to test_free_dir
    if (label==0): # free image
        src = abs_path
        dst = os.path.join("/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/test/free",fname)
        shutil.copyfile(src, dst)
    # Copy busy images to test_busy_dir
    if (label==1): # busy image
        src = abs_path
        dst = os.path.join("/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/test/busy",fname)
        shutil.copyfile(src, dst)

# %%
train_dir = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/train"
validation_dir = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/validation"

# %%
# Data Preprocessing
from keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# /root/anaconda3/envs/tf1.2_gpu/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Found 94493 images belonging to 2 classes.
# Found 18647 images belonging to 2 classes.

# %%
# building network
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
# read txt file
lines = []

txt_file = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/LABELS/train.txt"
with open(txt_file, "r") as txtfile:
    reader = txtfile.readlines()
    for line in reader:
        #print(line)
        lines.append(line)

# %%
line = lines[0]

# %%
relative_path = line[:-3]
relative_path
# Out:
# 'SUNNY/2016-01-12/camera6/S_2016-01-12_13.50_C06_240.jpg'

# %%
"/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/" + relative_path
# Out:
# '/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/SUNNY/2016-01-12/camera6/S_2016-01-12_13.50_C06_240.jpg'

# %%
label = line[-2:-1]
label
# Out:
# '1'

# %%
for line in lines:
    relative_path = line[:-3]
    label = line[-2:-1]
    abs_path = "/data/code4/deep-parking/dataset/CNR-EXT-Patches-150x150/PATCHES/" + relative_path
    # use cv2.imread() to load image patches (loaded as BGR format)
    #img = cv2.imread(abs_path)
    # use matplotlib.image to load image patches (loaded as RGB format)
    img = mpimg.imread(abs_path)

# %%
for line in lines:
    print(line[0])
    print(line[1])  
  #source_path = line[0]
  #tokens = source_path.split('/')
  #print(tokens)
# Out:
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# S
# U
# ...

# %%
lines
# Out:
# ['SUNNY/2016-01-12/camera6/S_2016-01-12_13.50_C06_240.jpg 1\n',
#  'SUNNY/2016-01-16/camera9/S_2016-01-16_17.10_C09_616.jpg 0\n',
#  'SUNNY/2015-11-22/camera7/S_2015-11-22_07.48_C07_274.jpg 0\n',
#  'SUNNY/2015-11-27/camera8/S_2015-11-27_16.44_C08_215.jpg 1\n',
#  'SUNNY/2016-01-18/camera6/S_2016-01-18_17.10_C06_274.jpg 0\n',
#  'SUNNY/2015-12-17/camera4/S_2015-12-17_12.51_C04_231.jpg 1\n',
#  'SUNNY/2015-12-10/camera5/S_2015-12-10_12.55_C05_270.jpg 1\n',
#  'SUNNY/2015-11-12/camera1/S_2015-11-12_11.39_C01_196.jpg 1\n',
#  'SUNNY/2015-12-10/camera9/S_2015-12-10_09.48_C09_617.jpg 1\n',
#  'SUNNY/2016-01-18/camera7/S_2016-01-18_10.15_C07_238.jpg 1\n',
#  'SUNNY/2016-01-15/camera4/S_2016-01-15_11.37_C04_226.jpg 1\n',
#  'SUNNY/2016-01-16/camera5/S_2016-01-16_08.42_C05_274.jpg 0\n',
#  'SUNNY/2016-01-18/camera1/S_2016-01-18_07.35_C01_262.jpg 0\n',
#  'SUNNY/2016-01-12/camera3/S_2016-01-12_09.47_C03_193.jpg 1\n',
#  'SUNNY/2016-01-13/camera2/S_2016-01-13_14.00_C02_601.jpg 1\n',
# ...
